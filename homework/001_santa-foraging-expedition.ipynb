# %% [markdown]
# # Overview
#
# Santa's reindeer typically eat regular reindeer food, but they need a lot of magical energy to deliver presents on Christmas. For that, their favorite snack is a special type of star fruit that only grows deep in the jungle. The Elves have brought you on their annual expedition to the grove where the fruit grows.
#
# The jungle must be too overgrown and difficult to navigate in vehicles or access from the air; the Elves' expedition traditionally goes on foot. As your boats approach land, the Elves begin taking inventory of their supplies. One important consideration is food - in particular, the number of Calories each Elf is carrying (your puzzle input).
#
# The Elves take turns writing down the number of Calories contained by the various meals, snacks, rations, etc. that they've brought with them, one item per line. Each Elf separates their own inventory from the previous Elf's inventory (if any) by a blank line.
#
# For example, suppose the Elves finish writing their items' Calories and end up with the following list:
# ```
# 1000
# 2000
# 3000
#
# 4000
#
# 5000
# 6000
#
# 7000
# 8000
# 9000
#
# 10000
# ```
# This list represents the Calories of the food carried by five Elves:
#
#   - The first Elf is carrying food with `1000`, `2000`, and `3000` Calories, a total of `6000` Calories.
#   - The second Elf is carrying one food item with `4000` Calories.
#   - The third Elf is carrying food with `5000` and `6000` Calories, a total of `11000` Calories.
#   - The fourth Elf is carrying food with `7000`, `8000`, and `9000` Calories, a total of `24000` Calories.
#   - The fifth Elf is carrying one food item with `10000` Calories.
#
# In case the Elves get hungry and need extra snacks, they need to know which Elf to ask: they'd like to know how many Calories are being carried by the Elf carrying the most Calories. In the example above, this is `24000` (carried by the fourth Elf).

# %% [markdown]
# # Part 1
#
# Using the file provided on Canvas, find the Elf carrying the most Calories. How many total Calories is that Elf carrying?

# %%
with open("/content/hw-001_foraging-expedition.txt", "r") as f:
    # list comprehension
    data = [
        int(line.strip())
        if line.strip().isnumeric()
        else line.strip()
        for line in f.readlines()
    ]

# %%
data[0:10]
# Out:
# [2494, 8013, 1055, 5425, 9104, 10665, '', 10642, 10677, 10300]

# %% [markdown]
# We have:
#
# - big long list of food items / calories
#
# We need:
#
# - what is the numeric representation of each item's calories?
# - how many elves?
# - what is each elf carrying?
# - store totals for each elf

# %%
from typing import List, Union
def split_on_blank(input: List[Union[int, str]]) -> List[List[int]]:
  results: List = []
  current_elf: List = []

  for elem in input:
    if type(elem) == int:
      current_elf.append(elem)
      print(f"appending {elem} to elf{len(results)+1}")
    else:
      results.append(current_elf)
      current_elf = []
    print(f"Finished elf {len(results)+1}'s inventory, moving to next")

  return results

# %%
elf_inventories = split_on_blank(data)
# Out:
# appending 2494 to elf1
# Finished elf 1's inventory, moving to next
# appending 8013 to elf1
# Finished elf 1's inventory, moving to next
# appending 1055 to elf1
# Finished elf 1's inventory, moving to next
# appending 5425 to elf1
# Finished elf 1's inventory, moving to next
# appending 9104 to elf1
# Finished elf 1's inventory, moving to next
# appending 10665 to elf1
# Finished elf 1's inventory, moving to next
# Finished elf 2's inventory, moving to next
# appending 10642 to elf2
# Finished elf 2's inventory, moving to next
# appending 10677 to elf2
# Finished elf 2's inventory, moving to next
# appending 10300 to elf2
# Finished elf 2's inventory, moving to next
# appending 7374 to elf2
# Finished elf 2's inventory, moving to next
# appending 9085 to elf2
# Finished elf 2's inventory, moving to next
# appending 8508 to elf2
# Finished elf 2's inventory, moving to next
# appending 7569 to elf2
# Finished elf 2's inventory, moving to next
# appending 6214 to elf2
# Finished elf 2's inventory, moving to next
# Finished elf 3's inventory, moving to next
# appending 5300 to elf3
# Finished elf 3's inventory, moving to next
# appending 5960 to elf3
# Finished elf 3's inventory, moving to next
# appending 8252 to elf3
# Finished elf 3's inventory, moving to next
# appending 5852 to elf3
# Finished elf 3's inventory, moving to next
# appending 4308 to elf3
# Finished elf 3's inventory, moving to next
# appending 9991 to elf3
# Finished elf 3's inventory, moving to next
# appending 6367 to elf3
# Finished elf 3's inventory, moving to next
# Finished elf 4's inventory, moving to next
# appending 1361 to elf4
# Finished elf 4's inventory, moving to next
# appending 5356 to elf4
# Finished elf 4's inventory, moving to next
# appending 6114 to elf4
# Finished elf 4's inventory, moving to next
# appending 3379 to elf4
# Finished elf 4's inventory, moving to next
# appending 5996 to elf4
# Finished elf 4's inventory, moving to next
# appending 3822 to elf4
# Finished elf 4's inventory, moving to next
# appending 3785 to elf4
# Finished elf 4's inventory, moving to next
# appending 1622 to elf4
# Finished elf 4's inventory, moving to next
# appending 1143 to elf4
# Finished elf 4's inventory, moving to next
# appending 6009 to elf4
# Finished elf 4's inventory, moving to next
# appending 2211 to elf4
# Finished elf 4's inventory, moving to next
# appending 4951 to elf4
# Finished elf 4's inventory, moving to next
# appending 3093 to elf4
# Finished elf 4's inventory, moving to next
# appending 6395 to elf4
# Finished elf 4's inventory, moving to next
# Finished elf 5's inventory, moving to next
# appending 4892 to elf5
# Finished elf 5's inventory, moving to next
# appending 6648 to elf5
# Finished elf 5's inventory, moving to next
# appending 3022 to elf5
# Finished elf 5's inventory, moving to next
# appending 6063 to elf5
# Finished elf 5's inventory, moving to next
# appending 5436 to elf5
# Finished elf 5's inventory, moving to next
# appending 2174 to elf5
# Finished elf 5's inventory, moving to next
# appending 4264 to elf5
# Finished elf 5's inventory, moving to next
# appending 2004 to elf5
# Finished elf 5's inventory, moving to next
# appending 6444 to elf5
# Finished elf 5's inventory, moving to next
# appending 2926 to elf5
# Finished elf 5's inventory, moving to next
# appending 2651 to elf5
# Finished elf 5's inventory, moving to next
# appending 2749 to elf5
# Finished elf 5's inventory, moving to next
# Finished elf 6's inventory, moving to next
# appending 17121 to elf6
# Finished elf 6's inventory, moving to next
# appending 17879 to elf6
# Finished elf 6's inventory, moving to next
# appending 11056 to elf6
# Finished elf 6's inventory, moving to next
# appending 15642 to elf6
# Finished elf 6's inventory, moving to next
# Finished elf 7's inventory, moving to next
# appending 3926 to elf7
# Finished elf 7's inventory, moving to next
# appending 6751 to elf7
# Finished elf 7's inventory, moving to next
# appending 2643 to elf7
# Finished elf 7's inventory, moving to next
# appending 7882 to elf7
# Finished elf 7's inventory, moving to next
# appending 4006 to elf7
# Finished elf 7's inventory, moving to next
# appending 1351 to elf7
# Finished elf 7's inventory, moving to next
# appending 4912 to elf7
# Finished elf 7's inventory, moving to next
# appending 2735 to elf7
# Finished elf 7's inventory, moving to next
# appending 2985 to elf7
# Finished elf 7's inventory, moving to next
# appending 4015 to elf7
# Finished elf 7's inventory, moving to next
# Finished elf 8's inventory, moving to next
# appending 3043 to elf8
# Finished elf 8's inventory, moving to next
# appending 6923 to elf8
# Finished elf 8's inventory, moving to next
# appending 10352 to elf8
# Finished elf 8's inventory, moving to next
# appending 9998 to elf8
# Finished elf 8's inventory, moving to next
# appending 2470 to elf8
# Finished elf 8's inventory, moving to next
# appending 7346 to elf8
# Finished elf 8's inventory, moving to next
# appending 1077 to elf8
# Finished elf 8's inventory, moving to next
# appending 3024 to elf8
# Finished elf 8's inventory, moving to next
# Finished elf 9's inventory, moving to next
# appending 21632 to elf9
# Finished elf 9's inventory, moving to next
# appending 34735 to elf9
# Finished elf 9's inventory, moving to next
# Finished elf 10's inventory, moving to next
# appending 8525 to elf10
# Finished elf 10's inventory, moving to next
# appending 1982 to elf10
# Finished elf 10's inventory, moving to next
# appending 9285 to elf10
# Finished elf 10's inventory, moving to next
# appending 4188 to elf10
# Finished elf 10's inventory, moving to next
# appending 7017 to elf10
# Finished elf 10's inventory, moving to next
# appending 6666 to elf10
# Finished elf 10's inventory, moving to next
# appending 6538 to elf10
# Finished elf 10's inventory, moving to next
# Finished elf 11's inventory, moving to next
# appending 7019 to elf11
# Finished elf 11's inventory, moving to next
# appending 2696 to elf11
# Finished elf 11's inventory, moving to next
# appending 2707 to elf11
# Finished elf 11's inventory, moving to next
# appending 3639 to elf11
# Finished elf 11's inventory, moving to next
# appending 3674 to elf11
# Finished elf 11's inventory, moving to next
# appending 3642 to elf11
# Finished elf 11's inventory, moving to next
# appending 4837 to elf11
# Finished elf 11's inventory, moving to next
# appending 3804 to elf11
# Finished elf 11's inventory, moving to next
# Finished elf 12's inventory, moving to next
# appending 3570 to elf12
# Finished elf 12's inventory, moving to next
# appending 8191 to elf12
# Finished elf 12's inventory, moving to next
# appending 6054 to elf12
# Finished elf 12's inventory, moving to next
# appending 8727 to elf12
# Finished elf 12's inventory, moving to next
# appending 7323 to elf12
# Finished elf 12's inventory, moving to next
# appending 3522 to elf12
# Finished elf 12's inventory, moving to next
# Finished elf 13's inventory, moving to next
# appending 1442 to elf13
# Finished elf 13's inventory, moving to next
# appending 5794 to elf13
# Finished elf 13's inventory, moving to next
# appending 3774 to elf13
# Finished elf 13's inventory, moving to next
# appending 2398 to elf13
# Finished elf 13's inventory, moving to next
# appending 5615 to elf13
# Finished elf 13's inventory, moving to next
# appending 5786 to elf13
# Finished elf 13's inventory, moving to next
# appending 1832 to elf13
# Finished elf 13's inventory, moving to next
# appending 2234 to elf13
# Finished elf 13's inventory, moving to next
# appending 7906 to elf13
# Finished elf 13's inventory, moving to next
# appending 4799 to elf13
# Finished elf 13's inventory, moving to next
# Finished elf 14's inventory, moving to next
# appending 12978 to elf14
# Finished elf 14's inventory, moving to next
# appending 17621 to elf14
# Finished elf 14's inventory, moving to next
# appending 9788 to elf14
# Finished elf 14's inventory, moving to next
# appending 9237 to elf14
# Finished elf 14's inventory, moving to next
# Finished elf 15's inventory, moving to next
# appending 3006 to elf15
# Finished elf 15's inventory, moving to next
# appending 2799 to elf15
# Finished elf 15's inventory, moving to next
# appending 5627 to elf15
# Finished elf 15's inventory, moving to next
# appending 2478 to elf15
# Finished elf 15's inventory, moving to next
# appending 3159 to elf15
# Finished elf 15's inventory, moving to next
# appending 6430 to elf15
# Finished elf 15's inventory, moving to next
# appending 3843 to elf15
# Finished elf 15's inventory, moving to next
# appending 1469 to elf15
# Finished elf 15's inventory, moving to next
# appending 2006 to elf15
# Finished elf 15's inventory, moving to next
# appending 4131 to elf15
# Finished elf 15's inventory, moving to next
# appending 2269 to elf15
# Finished elf 15's inventory, moving to next
# appending 6201 to elf15
# Finished elf 15's inventory, moving to next
# appending 3593 to elf15
# Finished elf 15's inventory, moving to next
# appending 1423 to elf15
# Finished elf 15's inventory, moving to next
# Finished elf 16's inventory, moving to next
# appending 30560 to elf16
# Finished elf 16's inventory, moving to next
# Finished elf 17's inventory, moving to next
# appending 5281 to elf17
# Finished elf 17's inventory, moving to next
# appending 3850 to elf17
# Finished elf 17's inventory, moving to next
# appending 2894 to elf17
# Finished elf 17's inventory, moving to next
# appending 4056 to elf17
# Finished elf 17's inventory, moving to next
# appending 4341 to elf17
# Finished elf 17's inventory, moving to next
# appending 4117 to elf17
# Finished elf 17's inventory, moving to next
# appending 8216 to elf17
# Finished elf 17's inventory, moving to next
# appending 2700 to elf17
# Finished elf 17's inventory, moving to next
# appending 1327 to elf17
# Finished elf 17's inventory, moving to next
# appending 2379 to elf17
# Finished elf 17's inventory, moving to next
# Finished elf 18's inventory, moving to next
# appending 1597 to elf18
# Finished elf 18's inventory, moving to next
# appending 7217 to elf18
# Finished elf 18's inventory, moving to next
# appending 1003 to elf18
# Finished elf 18's inventory, moving to next
# appending 2555 to elf18
# Finished elf 18's inventory, moving to next
# appending 4820 to elf18
# Finished elf 18's inventory, moving to next
# appending 2881 to elf18
# Finished elf 18's inventory, moving to next
# appending 4051 to elf18
# Finished elf 18's inventory, moving to next
# appending 4550 to elf18
# Finished elf 18's inventory, moving to next
# appending 2457 to elf18
# Finished elf 18's inventory, moving to next
# appending 6518 to elf18
# Finished elf 18's inventory, moving to next
# appending 5480 to elf18
# Finished elf 18's inventory, moving to next
# appending 3044 to elf18
# Finished elf 18's inventory, moving to next
# Finished elf 19's inventory, moving to next
# appending 9465 to elf19
# Finished elf 19's inventory, moving to next
# appending 4325 to elf19
# Finished elf 19's inventory, moving to next
# appending 5593 to elf19
# Finished elf 19's inventory, moving to next
# appending 5606 to elf19
# Finished elf 19's inventory, moving to next
# appending 9317 to elf19
# Finished elf 19's inventory, moving to next
# appending 1026 to elf19
# Finished elf 19's inventory, moving to next
# appending 3707 to elf19
# Finished elf 19's inventory, moving to next
# appending 9456 to elf19
# Finished elf 19's inventory, moving to next
# appending 7801 to elf19
# Finished elf 19's inventory, moving to next
# Finished elf 20's inventory, moving to next
# appending 6217 to elf20
# Finished elf 20's inventory, moving to next
# appending 7814 to elf20
# Finished elf 20's inventory, moving to next
# appending 3159 to elf20
# Finished elf 20's inventory, moving to next
# appending 3866 to elf20
# Finished elf 20's inventory, moving to next
# appending 1035 to elf20
# Finished elf 20's inventory, moving to next
# appending 4302 to elf20
# Finished elf 20's inventory, moving to next
# appending 1498 to elf20
# Finished elf 20's inventory, moving to next
# appending 1160 to elf20
# Finished elf 20's inventory, moving to next
# appending 1510 to elf20
# Finished elf 20's inventory, moving to next
# appending 4650 to elf20
# Finished elf 20's inventory, moving to next
# Finished elf 21's inventory, moving to next
# appending 13306 to elf21
# Finished elf 21's inventory, moving to next
# appending 15884 to elf21
# Finished elf 21's inventory, moving to next
# appending 9699 to elf21
# Finished elf 21's inventory, moving to next
# appending 11206 to elf21
# Finished elf 21's inventory, moving to next
# Finished elf 22's inventory, moving to next
# appending 24775 to elf22
# Finished elf 22's inventory, moving to next
# appending 21119 to elf22
# Finished elf 22's inventory, moving to next
# appending 12643 to elf22
# Finished elf 22's inventory, moving to next
# Finished elf 23's inventory, moving to next
# appending 12737 to elf23
# Finished elf 23's inventory, moving to next
# appending 10893 to elf23
# Finished elf 23's inventory, moving to next
# appending 3450 to elf23
# Finished elf 23's inventory, moving to next
# appending 10732 to elf23
# Finished elf 23's inventory, moving to next
# appending 8670 to elf23
# Finished elf 23's inventory, moving to next
# appending 7597 to elf23
# Finished elf 23's inventory, moving to next
# Finished elf 24's inventory, moving to next
# appending 35714 to elf24
# Finished elf 24's inventory, moving to next
# Finished elf 25's inventory, moving to next
# appending 3380 to elf25
# Finished elf 25's inventory, moving to next
# appending 3513 to elf25
# Finished elf 25's inventory, moving to next
# appending 6559 to elf25
# Finished elf 25's inventory, moving to next
# appending 6891 to elf25
# Finished elf 25's inventory, moving to next
# appending 7767 to elf25
# Finished elf 25's inventory, moving to next
# appending 5311 to elf25
# Finished elf 25's inventory, moving to next
# appending 7086 to elf25
# Finished elf 25's inventory, moving to next
# appending 5345 to elf25
# Finished elf 25's inventory, moving to next
# appending 3498 to elf25
# Finished elf 25's inventory, moving to next
# appending 3091 to elf25
# Finished elf 25's inventory, moving to next
# appending 2516 to elf25
# Finished elf 25's inventory, moving to next
# Finished elf 26's inventory, moving to next
# appending 11565 to elf26
# Finished elf 26's inventory, moving to next
# appending 12877 to elf26
# Finished elf 26's inventory, moving to next
# appending 13416 to elf26
# Finished elf 26's inventory, moving to next
# appending 10568 to elf26
# Finished elf 26's inventory, moving to next
# appending 16033 to elf26
# Finished elf 26's inventory, moving to next
# Finished elf 27's inventory, moving to next
# appending 1380 to elf27
# Finished elf 27's inventory, moving to next
# appending 4192 to elf27
# Finished elf 27's inventory, moving to next
# appending 5815 to elf27
# Finished elf 27's inventory, moving to next
# appending 6230 to elf27
# Finished elf 27's inventory, moving to next
# appending 2434 to elf27
# Finished elf 27's inventory, moving to next
# appending 2443 to elf27
# Finished elf 27's inventory, moving to next
# appending 3682 to elf27
# Finished elf 27's inventory, moving to next
# appending 5568 to elf27
# Finished elf 27's inventory, moving to next
# appending 6134 to elf27
# Finished elf 27's inventory, moving to next
# appending 3316 to elf27
# Finished elf 27's inventory, moving to next
# appending 5878 to elf27
# Finished elf 27's inventory, moving to next
# appending 4493 to elf27
# Finished elf 27's inventory, moving to next
# appending 3857 to elf27
# Finished elf 27's inventory, moving to next
# appending 2110 to elf27
# Finished elf 27's inventory, moving to next
# Finished elf 28's inventory, moving to next
# appending 4341 to elf28
# Finished elf 28's inventory, moving to next
# appending 2469 to elf28
# Finished elf 28's inventory, moving to next
# appending 5606 to elf28
# Finished elf 28's inventory, moving to next
# appending 4268 to elf28
# Finished elf 28's inventory, moving to next
# appending 3525 to elf28
# Finished elf 28's inventory, moving to next
# appending 5555 to elf28
# Finished elf 28's inventory, moving to next
# appending 5771 to elf28
# Finished elf 28's inventory, moving to next
# appending 2284 to elf28
# Finished elf 28's inventory, moving to next
# appending 1921 to elf28
# Finished elf 28's inventory, moving to next
# appending 3279 to elf28
# Finished elf 28's inventory, moving to next
# appending 1901 to elf28
# Finished elf 28's inventory, moving to next
# appending 5991 to elf28
# Finished elf 28's inventory, moving to next
# appending 2868 to elf28
# Finished elf 28's inventory, moving to next
# appending 4866 to elf28
# Finished elf 28's inventory, moving to next
# appending 2310 to elf28
# Finished elf 28's inventory, moving to next
# Finished elf 29's inventory, moving to next
# appending 5969 to elf29
# Finished elf 29's inventory, moving to next
# appending 18172 to elf29
# Finished elf 29's inventory, moving to next
# appending 1931 to elf29
# Finished elf 29's inventory, moving to next
# Finished elf 30's inventory, moving to next
# appending 3598 to elf30
# Finished elf 30's inventory, moving to next
# appending 2837 to elf30
# Finished elf 30's inventory, moving to next
# appending 1105 to elf30
# Finished elf 30's inventory, moving to next
# appending 7300 to elf30
# Finished elf 30's inventory, moving to next
# appending 11781 to elf30
# Finished elf 30's inventory, moving to next
# appending 10686 to elf30
# Finished elf 30's inventory, moving to next
# Finished elf 31's inventory, moving to next
# appending 3698 to elf31
# Finished elf 31's inventory, moving to next
# appending 4698 to elf31
# Finished elf 31's inventory, moving to next
# appending 3891 to elf31
# Finished elf 31's inventory, moving to next
# appending 4481 to elf31
# Finished elf 31's inventory, moving to next
# appending 4089 to elf31
# Finished elf 31's inventory, moving to next
# appending 3511 to elf31
# Finished elf 31's inventory, moving to next
# appending 4949 to elf31
# Finished elf 31's inventory, moving to next
# appending 2148 to elf31
# Finished elf 31's inventory, moving to next
# appending 4017 to elf31
# Finished elf 31's inventory, moving to next
# appending 2529 to elf31
# Finished elf 31's inventory, moving to next
# appending 3572 to elf31
# Finished elf 31's inventory, moving to next
# appending 1912 to elf31
# Finished elf 31's inventory, moving to next
# appending 1837 to elf31
# Finished elf 31's inventory, moving to next
# appending 1937 to elf31
# Finished elf 31's inventory, moving to next
# appending 2688 to elf31
# Finished elf 31's inventory, moving to next
# Finished elf 32's inventory, moving to next
# appending 6485 to elf32
# Finished elf 32's inventory, moving to next
# appending 7072 to elf32
# Finished elf 32's inventory, moving to next
# appending 7964 to elf32
# Finished elf 32's inventory, moving to next
# appending 13114 to elf32
# Finished elf 32's inventory, moving to next
# appending 5864 to elf32
# Finished elf 32's inventory, moving to next
# appending 5280 to elf32
# Finished elf 32's inventory, moving to next
# Finished elf 33's inventory, moving to next
# appending 12413 to elf33
# Finished elf 33's inventory, moving to next
# appending 7196 to elf33
# Finished elf 33's inventory, moving to next
# appending 12856 to elf33
# Finished elf 33's inventory, moving to next
# appending 18069 to elf33
# Finished elf 33's inventory, moving to next
# Finished elf 34's inventory, moving to next
# appending 1367 to elf34
# Finished elf 34's inventory, moving to next
# appending 2238 to elf34
# Finished elf 34's inventory, moving to next
# appending 3089 to elf34
# Finished elf 34's inventory, moving to next
# appending 3189 to elf34
# Finished elf 34's inventory, moving to next
# appending 5022 to elf34
# Finished elf 34's inventory, moving to next
# appending 3877 to elf34
# Finished elf 34's inventory, moving to next
# appending 5238 to elf34
# Finished elf 34's inventory, moving to next
# appending 3566 to elf34
# Finished elf 34's inventory, moving to next
# appending 1081 to elf34
# Finished elf 34's inventory, moving to next
# appending 1525 to elf34
# Finished elf 34's inventory, moving to next
# appending 1958 to elf34
# Finished elf 34's inventory, moving to next
# appending 5796 to elf34
# Finished elf 34's inventory, moving to next
# appending 2498 to elf34
# Finished elf 34's inventory, moving to next
# appending 1517 to elf34
# Finished elf 34's inventory, moving to next
# appending 1481 to elf34
# Finished elf 34's inventory, moving to next
# Finished elf 35's inventory, moving to next
# appending 25527 to elf35
# Finished elf 35's inventory, moving to next
# appending 17474 to elf35
# Finished elf 35's inventory, moving to next
# appending 4705 to elf35
# Finished elf 35's inventory, moving to next
# Finished elf 36's inventory, moving to next
# appending 6722 to elf36
# Finished elf 36's inventory, moving to next
# appending 2844 to elf36
# Finished elf 36's inventory, moving to next
# appending 3856 to elf36
# Finished elf 36's inventory, moving to next
# appending 1780 to elf36
# Finished elf 36's inventory, moving to next
# appending 4518 to elf36
# Finished elf 36's inventory, moving to next
# appending 5679 to elf36
# Finished elf 36's inventory, moving to next
# appending 4775 to elf36
# Finished elf 36's inventory, moving to next
# appending 6067 to elf36
# Finished elf 36's inventory, moving to next
# appending 2695 to elf36
# Finished elf 36's inventory, moving to next
# appending 5979 to elf36
# Finished elf 36's inventory, moving to next
# appending 2488 to elf36
# Finished elf 36's inventory, moving to next
# appending 1515 to elf36
# Finished elf 36's inventory, moving to next
# appending 5071 to elf36
# Finished elf 36's inventory, moving to next
# Finished elf 37's inventory, moving to next
# appending 7155 to elf37
# Finished elf 37's inventory, moving to next
# appending 4147 to elf37
# Finished elf 37's inventory, moving to next
# appending 4406 to elf37
# Finished elf 37's inventory, moving to next
# appending 4169 to elf37
# Finished elf 37's inventory, moving to next
# appending 2156 to elf37
# Finished elf 37's inventory, moving to next
# appending 7110 to elf37
# Finished elf 37's inventory, moving to next
# appending 6837 to elf37
# Finished elf 37's inventory, moving to next
# appending 4673 to elf37
# Finished elf 37's inventory, moving to next
# appending 3599 to elf37
# Finished elf 37's inventory, moving to next
# appending 2672 to elf37
# Finished elf 37's inventory, moving to next
# appending 2768 to elf37
# Finished elf 37's inventory, moving to next
# appending 3195 to elf37
# Finished elf 37's inventory, moving to next
# Finished elf 38's inventory, moving to next
# appending 8040 to elf38
# Finished elf 38's inventory, moving to next
# appending 5248 to elf38
# Finished elf 38's inventory, moving to next
# appending 6440 to elf38
# Finished elf 38's inventory, moving to next
# appending 1830 to elf38
# Finished elf 38's inventory, moving to next
# appending 2281 to elf38
# Finished elf 38's inventory, moving to next
# appending 4938 to elf38
# Finished elf 38's inventory, moving to next
# appending 6116 to elf38
# Finished elf 38's inventory, moving to next
# appending 6842 to elf38
# Finished elf 38's inventory, moving to next
# appending 5743 to elf38
# Finished elf 38's inventory, moving to next
# appending 5788 to elf38
# Finished elf 38's inventory, moving to next
# appending 5703 to elf38
# Finished elf 38's inventory, moving to next
# Finished elf 39's inventory, moving to next
# appending 2527 to elf39
# Finished elf 39's inventory, moving to next
# appending 3362 to elf39
# Finished elf 39's inventory, moving to next
# appending 5630 to elf39
# Finished elf 39's inventory, moving to next
# appending 4976 to elf39
# Finished elf 39's inventory, moving to next
# appending 1989 to elf39
# Finished elf 39's inventory, moving to next
# appending 5157 to elf39
# Finished elf 39's inventory, moving to next
# appending 4951 to elf39
# Finished elf 39's inventory, moving to next
# appending 3382 to elf39
# Finished elf 39's inventory, moving to next
# appending 4525 to elf39
# Finished elf 39's inventory, moving to next
# appending 4057 to elf39
# Finished elf 39's inventory, moving to next
# appending 4077 to elf39
# Finished elf 39's inventory, moving to next
# appending 3717 to elf39
# Finished elf 39's inventory, moving to next
# appending 4035 to elf39
# Finished elf 39's inventory, moving to next
# appending 4907 to elf39
# Finished elf 39's inventory, moving to next
# appending 1795 to elf39
# Finished elf 39's inventory, moving to next
# Finished elf 40's inventory, moving to next
# appending 1069 to elf40
# Finished elf 40's inventory, moving to next
# appending 7242 to elf40
# Finished elf 40's inventory, moving to next
# appending 2438 to elf40
# Finished elf 40's inventory, moving to next
# appending 7224 to elf40
# Finished elf 40's inventory, moving to next
# appending 8058 to elf40
# Finished elf 40's inventory, moving to next
# appending 6215 to elf40
# Finished elf 40's inventory, moving to next
# appending 7770 to elf40
# Finished elf 40's inventory, moving to next
# appending 5958 to elf40
# Finished elf 40's inventory, moving to next
# appending 2445 to elf40
# Finished elf 40's inventory, moving to next
# appending 1702 to elf40
# Finished elf 40's inventory, moving to next
# appending 3558 to elf40
# Finished elf 40's inventory, moving to next
# Finished elf 41's inventory, moving to next
# appending 6075 to elf41
# Finished elf 41's inventory, moving to next
# appending 4164 to elf41
# Finished elf 41's inventory, moving to next
# appending 5797 to elf41
# Finished elf 41's inventory, moving to next
# appending 1051 to elf41
# Finished elf 41's inventory, moving to next
# appending 3104 to elf41
# Finished elf 41's inventory, moving to next
# appending 2966 to elf41
# Finished elf 41's inventory, moving to next
# appending 3653 to elf41
# Finished elf 41's inventory, moving to next
# appending 3933 to elf41
# Finished elf 41's inventory, moving to next
# appending 1546 to elf41
# Finished elf 41's inventory, moving to next
# appending 5111 to elf41
# Finished elf 41's inventory, moving to next
# appending 4811 to elf41
# Finished elf 41's inventory, moving to next
# appending 4145 to elf41
# Finished elf 41's inventory, moving to next
# appending 3532 to elf41
# Finished elf 41's inventory, moving to next
# appending 2289 to elf41
# Finished elf 41's inventory, moving to next
# appending 1468 to elf41
# Finished elf 41's inventory, moving to next
# Finished elf 42's inventory, moving to next
# appending 9540 to elf42
# Finished elf 42's inventory, moving to next
# Finished elf 43's inventory, moving to next
# appending 1830 to elf43
# Finished elf 43's inventory, moving to next
# appending 6422 to elf43
# Finished elf 43's inventory, moving to next
# appending 7523 to elf43
# Finished elf 43's inventory, moving to next
# appending 2131 to elf43
# Finished elf 43's inventory, moving to next
# appending 3072 to elf43
# Finished elf 43's inventory, moving to next
# appending 2873 to elf43
# Finished elf 43's inventory, moving to next
# appending 1423 to elf43
# Finished elf 43's inventory, moving to next
# appending 7560 to elf43
# Finished elf 43's inventory, moving to next
# appending 4640 to elf43
# Finished elf 43's inventory, moving to next
# appending 4476 to elf43
# Finished elf 43's inventory, moving to next
# Finished elf 44's inventory, moving to next
# appending 10022 to elf44
# Finished elf 44's inventory, moving to next
# appending 15927 to elf44
# Finished elf 44's inventory, moving to next
# appending 14403 to elf44
# Finished elf 44's inventory, moving to next
# appending 2312 to elf44
# Finished elf 44's inventory, moving to next
# Finished elf 45's inventory, moving to next
# appending 3056 to elf45
# Finished elf 45's inventory, moving to next
# appending 5371 to elf45
# Finished elf 45's inventory, moving to next
# appending 4501 to elf45
# Finished elf 45's inventory, moving to next
# appending 6465 to elf45
# Finished elf 45's inventory, moving to next
# appending 4761 to elf45
# Finished elf 45's inventory, moving to next
# appending 2050 to elf45
# Finished elf 45's inventory, moving to next
# appending 4187 to elf45
# Finished elf 45's inventory, moving to next
# appending 1179 to elf45
# Finished elf 45's inventory, moving to next
# appending 3746 to elf45
# Finished elf 45's inventory, moving to next
# appending 6089 to elf45
# Finished elf 45's inventory, moving to next
# appending 1365 to elf45
# Finished elf 45's inventory, moving to next
# appending 6495 to elf45
# Finished elf 45's inventory, moving to next
# appending 4844 to elf45
# Finished elf 45's inventory, moving to next
# appending 4984 to elf45
# Finished elf 45's inventory, moving to next
# Finished elf 46's inventory, moving to next
# appending 1812 to elf46
# Finished elf 46's inventory, moving to next
# appending 2671 to elf46
# Finished elf 46's inventory, moving to next
# appending 1805 to elf46
# Finished elf 46's inventory, moving to next
# appending 4200 to elf46
# Finished elf 46's inventory, moving to next
# appending 1986 to elf46
# Finished elf 46's inventory, moving to next
# appending 5327 to elf46
# Finished elf 46's inventory, moving to next
# appending 5548 to elf46
# Finished elf 46's inventory, moving to next
# appending 1872 to elf46
# Finished elf 46's inventory, moving to next
# appending 4364 to elf46
# Finished elf 46's inventory, moving to next
# appending 3147 to elf46
# Finished elf 46's inventory, moving to next
# appending 5447 to elf46
# Finished elf 46's inventory, moving to next
# appending 5882 to elf46
# Finished elf 46's inventory, moving to next
# appending 2602 to elf46
# Finished elf 46's inventory, moving to next
# appending 5501 to elf46
# Finished elf 46's inventory, moving to next
# appending 2446 to elf46
# Finished elf 46's inventory, moving to next
# Finished elf 47's inventory, moving to next
# appending 9725 to elf47
# Finished elf 47's inventory, moving to next
# appending 8080 to elf47
# Finished elf 47's inventory, moving to next
# appending 9941 to elf47
# Finished elf 47's inventory, moving to next
# appending 10636 to elf47
# Finished elf 47's inventory, moving to next
# appending 6852 to elf47
# Finished elf 47's inventory, moving to next
# appending 5378 to elf47
# Finished elf 47's inventory, moving to next
# appending 4137 to elf47
# Finished elf 47's inventory, moving to next
# Finished elf 48's inventory, moving to next
# appending 25228 to elf48
# Finished elf 48's inventory, moving to next
# appending 22215 to elf48
# Finished elf 48's inventory, moving to next
# appending 10199 to elf48
# Finished elf 48's inventory, moving to next
# Finished elf 49's inventory, moving to next
# appending 15394 to elf49
# Finished elf 49's inventory, moving to next
# appending 28799 to elf49
# Finished elf 49's inventory, moving to next
# Finished elf 50's inventory, moving to next
# appending 3620 to elf50
# Finished elf 50's inventory, moving to next
# appending 1758 to elf50
# Finished elf 50's inventory, moving to next
# appending 4663 to elf50
# Finished elf 50's inventory, moving to next
# appending 2715 to elf50
# Finished elf 50's inventory, moving to next
# appending 5642 to elf50
# Finished elf 50's inventory, moving to next
# appending 6209 to elf50
# Finished elf 50's inventory, moving to next
# appending 5361 to elf50
# Finished elf 50's inventory, moving to next
# appending 4582 to elf50
# Finished elf 50's inventory, moving to next
# appending 2165 to elf50
# Finished elf 50's inventory, moving to next
# appending 7485 to elf50
# Finished elf 50's inventory, moving to next
# appending 7611 to elf50
# Finished elf 50's inventory, moving to next
# Finished elf 51's inventory, moving to next
# appending 6910 to elf51
# Finished elf 51's inventory, moving to next
# appending 6782 to elf51
# Finished elf 51's inventory, moving to next
# appending 2177 to elf51
# Finished elf 51's inventory, moving to next
# appending 2763 to elf51
# Finished elf 51's inventory, moving to next
# appending 6877 to elf51
# Finished elf 51's inventory, moving to next
# appending 3922 to elf51
# Finished elf 51's inventory, moving to next
# appending 1355 to elf51
# Finished elf 51's inventory, moving to next
# appending 2400 to elf51
# Finished elf 51's inventory, moving to next
# appending 6139 to elf51
# Finished elf 51's inventory, moving to next
# appending 5362 to elf51
# Finished elf 51's inventory, moving to next
# appending 5737 to elf51
# Finished elf 51's inventory, moving to next
# appending 3766 to elf51
# Finished elf 51's inventory, moving to next
# appending 3535 to elf51
# Finished elf 51's inventory, moving to next
# Finished elf 52's inventory, moving to next
# appending 6587 to elf52
# Finished elf 52's inventory, moving to next
# appending 6770 to elf52
# Finished elf 52's inventory, moving to next
# appending 3729 to elf52
# Finished elf 52's inventory, moving to next
# appending 3316 to elf52
# Finished elf 52's inventory, moving to next
# appending 4161 to elf52
# Finished elf 52's inventory, moving to next
# appending 2828 to elf52
# Finished elf 52's inventory, moving to next
# appending 3886 to elf52
# Finished elf 52's inventory, moving to next
# appending 7483 to elf52
# Finished elf 52's inventory, moving to next
# appending 2746 to elf52
# Finished elf 52's inventory, moving to next
# appending 5923 to elf52
# Finished elf 52's inventory, moving to next
# Finished elf 53's inventory, moving to next
# appending 1647 to elf53
# Finished elf 53's inventory, moving to next
# appending 6201 to elf53
# Finished elf 53's inventory, moving to next
# appending 1200 to elf53
# Finished elf 53's inventory, moving to next
# appending 5810 to elf53
# Finished elf 53's inventory, moving to next
# appending 4493 to elf53
# Finished elf 53's inventory, moving to next
# appending 5373 to elf53
# Finished elf 53's inventory, moving to next
# appending 1856 to elf53
# Finished elf 53's inventory, moving to next
# appending 5507 to elf53
# Finished elf 53's inventory, moving to next
# appending 1833 to elf53
# Finished elf 53's inventory, moving to next
# appending 4277 to elf53
# Finished elf 53's inventory, moving to next
# appending 2897 to elf53
# Finished elf 53's inventory, moving to next
# appending 4473 to elf53
# Finished elf 53's inventory, moving to next
# appending 4433 to elf53
# Finished elf 53's inventory, moving to next
# appending 4352 to elf53
# Finished elf 53's inventory, moving to next
# Finished elf 54's inventory, moving to next
# appending 3807 to elf54
# Finished elf 54's inventory, moving to next
# appending 18028 to elf54
# Finished elf 54's inventory, moving to next
# appending 7426 to elf54
# Finished elf 54's inventory, moving to next
# appending 18476 to elf54
# Finished elf 54's inventory, moving to next
# Finished elf 55's inventory, moving to next
# appending 6493 to elf55
# Finished elf 55's inventory, moving to next
# appending 1157 to elf55
# Finished elf 55's inventory, moving to next
# appending 3125 to elf55
# Finished elf 55's inventory, moving to next
# appending 7736 to elf55
# Finished elf 55's inventory, moving to next
# appending 1208 to elf55
# Finished elf 55's inventory, moving to next
# appending 3243 to elf55
# Finished elf 55's inventory, moving to next
# appending 7737 to elf55
# Finished elf 55's inventory, moving to next
# appending 1953 to elf55
# Finished elf 55's inventory, moving to next
# appending 1970 to elf55
# Finished elf 55's inventory, moving to next
# appending 3245 to elf55
# Finished elf 55's inventory, moving to next
# appending 1600 to elf55
# Finished elf 55's inventory, moving to next
# Finished elf 56's inventory, moving to next
# appending 12034 to elf56
# Finished elf 56's inventory, moving to next
# appending 12959 to elf56
# Finished elf 56's inventory, moving to next
# appending 9334 to elf56
# Finished elf 56's inventory, moving to next
# Finished elf 57's inventory, moving to next
# appending 8432 to elf57
# Finished elf 57's inventory, moving to next
# appending 3424 to elf57
# Finished elf 57's inventory, moving to next
# appending 4506 to elf57
# Finished elf 57's inventory, moving to next
# appending 5758 to elf57
# Finished elf 57's inventory, moving to next
# appending 10840 to elf57
# Finished elf 57's inventory, moving to next
# appending 11056 to elf57
# Finished elf 57's inventory, moving to next
# Finished elf 58's inventory, moving to next
# appending 7284 to elf58
# Finished elf 58's inventory, moving to next
# appending 4013 to elf58
# Finished elf 58's inventory, moving to next
# appending 4217 to elf58
# Finished elf 58's inventory, moving to next
# appending 7307 to elf58
# Finished elf 58's inventory, moving to next
# appending 6367 to elf58
# Finished elf 58's inventory, moving to next
# appending 1977 to elf58
# Finished elf 58's inventory, moving to next
# appending 3617 to elf58
# Finished elf 58's inventory, moving to next
# appending 2165 to elf58
# Finished elf 58's inventory, moving to next
# appending 2969 to elf58
# Finished elf 58's inventory, moving to next
# appending 6595 to elf58
# Finished elf 58's inventory, moving to next
# appending 6651 to elf58
# Finished elf 58's inventory, moving to next
# appending 2446 to elf58
# Finished elf 58's inventory, moving to next
# Finished elf 59's inventory, moving to next
# appending 1083 to elf59
# Finished elf 59's inventory, moving to next
# appending 5636 to elf59
# Finished elf 59's inventory, moving to next
# appending 1785 to elf59
# Finished elf 59's inventory, moving to next
# appending 2553 to elf59
# Finished elf 59's inventory, moving to next
# appending 4634 to elf59
# Finished elf 59's inventory, moving to next
# appending 3790 to elf59
# Finished elf 59's inventory, moving to next
# appending 7465 to elf59
# Finished elf 59's inventory, moving to next
# appending 2970 to elf59
# Finished elf 59's inventory, moving to next
# appending 2725 to elf59
# Finished elf 59's inventory, moving to next
# appending 4267 to elf59
# Finished elf 59's inventory, moving to next
# appending 2861 to elf59
# Finished elf 59's inventory, moving to next
# Finished elf 60's inventory, moving to next
# appending 3145 to elf60
# Finished elf 60's inventory, moving to next
# appending 7872 to elf60
# Finished elf 60's inventory, moving to next
# appending 5049 to elf60
# Finished elf 60's inventory, moving to next
# appending 3368 to elf60
# Finished elf 60's inventory, moving to next
# appending 4009 to elf60
# Finished elf 60's inventory, moving to next
# appending 2348 to elf60
# Finished elf 60's inventory, moving to next
# appending 6877 to elf60
# Finished elf 60's inventory, moving to next
# appending 6956 to elf60
# Finished elf 60's inventory, moving to next
# appending 2359 to elf60
# Finished elf 60's inventory, moving to next
# appending 8064 to elf60
# Finished elf 60's inventory, moving to next
# appending 4386 to elf60
# Finished elf 60's inventory, moving to next
# Finished elf 61's inventory, moving to next
# appending 4764 to elf61
# Finished elf 61's inventory, moving to next
# appending 6236 to elf61
# Finished elf 61's inventory, moving to next
# appending 4923 to elf61
# Finished elf 61's inventory, moving to next
# appending 4395 to elf61
# Finished elf 61's inventory, moving to next
# appending 2974 to elf61
# Finished elf 61's inventory, moving to next
# appending 3985 to elf61
# Finished elf 61's inventory, moving to next
# appending 2725 to elf61
# Finished elf 61's inventory, moving to next
# appending 1831 to elf61
# Finished elf 61's inventory, moving to next
# appending 2755 to elf61
# Finished elf 61's inventory, moving to next
# appending 4068 to elf61
# Finished elf 61's inventory, moving to next
# appending 2383 to elf61
# Finished elf 61's inventory, moving to next
# appending 2138 to elf61
# Finished elf 61's inventory, moving to next
# appending 2998 to elf61
# Finished elf 61's inventory, moving to next
# appending 4346 to elf61
# Finished elf 61's inventory, moving to next
# Finished elf 62's inventory, moving to next
# appending 6673 to elf62
# Finished elf 62's inventory, moving to next
# appending 2519 to elf62
# Finished elf 62's inventory, moving to next
# appending 2754 to elf62
# Finished elf 62's inventory, moving to next
# appending 5734 to elf62
# Finished elf 62's inventory, moving to next
# appending 4796 to elf62
# Finished elf 62's inventory, moving to next
# appending 3389 to elf62
# Finished elf 62's inventory, moving to next
# appending 6931 to elf62
# Finished elf 62's inventory, moving to next
# appending 5771 to elf62
# Finished elf 62's inventory, moving to next
# appending 5936 to elf62
# Finished elf 62's inventory, moving to next
# appending 2328 to elf62
# Finished elf 62's inventory, moving to next
# appending 5684 to elf62
# Finished elf 62's inventory, moving to next
# appending 3171 to elf62
# Finished elf 62's inventory, moving to next
# appending 4608 to elf62
# Finished elf 62's inventory, moving to next
# Finished elf 63's inventory, moving to next
# appending 15166 to elf63
# Finished elf 63's inventory, moving to next
# appending 11415 to elf63
# Finished elf 63's inventory, moving to next
# appending 9051 to elf63
# Finished elf 63's inventory, moving to next
# appending 3437 to elf63
# Finished elf 63's inventory, moving to next
# appending 10405 to elf63
# Finished elf 63's inventory, moving to next
# Finished elf 64's inventory, moving to next
# appending 1590 to elf64
# Finished elf 64's inventory, moving to next
# appending 7370 to elf64
# Finished elf 64's inventory, moving to next
# appending 7003 to elf64
# Finished elf 64's inventory, moving to next
# appending 5030 to elf64
# Finished elf 64's inventory, moving to next
# appending 3852 to elf64
# Finished elf 64's inventory, moving to next
# appending 6353 to elf64
# Finished elf 64's inventory, moving to next
# appending 7054 to elf64
# Finished elf 64's inventory, moving to next
# appending 3765 to elf64
# Finished elf 64's inventory, moving to next
# appending 2925 to elf64
# Finished elf 64's inventory, moving to next
# appending 6968 to elf64
# Finished elf 64's inventory, moving to next
# Finished elf 65's inventory, moving to next
# appending 9678 to elf65
# Finished elf 65's inventory, moving to next
# appending 2846 to elf65
# Finished elf 65's inventory, moving to next
# appending 8939 to elf65
# Finished elf 65's inventory, moving to next
# appending 10270 to elf65
# Finished elf 65's inventory, moving to next
# appending 7196 to elf65
# Finished elf 65's inventory, moving to next
# appending 11860 to elf65
# Finished elf 65's inventory, moving to next
# appending 4221 to elf65
# Finished elf 65's inventory, moving to next
# Finished elf 66's inventory, moving to next
# appending 4447 to elf66
# Finished elf 66's inventory, moving to next
# appending 5407 to elf66
# Finished elf 66's inventory, moving to next
# appending 1459 to elf66
# Finished elf 66's inventory, moving to next
# appending 1693 to elf66
# Finished elf 66's inventory, moving to next
# appending 3774 to elf66
# Finished elf 66's inventory, moving to next
# appending 3978 to elf66
# Finished elf 66's inventory, moving to next
# appending 5240 to elf66
# Finished elf 66's inventory, moving to next
# appending 2331 to elf66
# Finished elf 66's inventory, moving to next
# appending 1903 to elf66
# Finished elf 66's inventory, moving to next
# appending 4421 to elf66
# Finished elf 66's inventory, moving to next
# appending 1152 to elf66
# Finished elf 66's inventory, moving to next
# appending 5084 to elf66
# Finished elf 66's inventory, moving to next
# appending 1969 to elf66
# Finished elf 66's inventory, moving to next
# appending 2365 to elf66
# Finished elf 66's inventory, moving to next
# appending 4526 to elf66
# Finished elf 66's inventory, moving to next
# Finished elf 67's inventory, moving to next
# appending 5249 to elf67
# Finished elf 67's inventory, moving to next
# appending 5631 to elf67
# Finished elf 67's inventory, moving to next
# appending 3701 to elf67
# Finished elf 67's inventory, moving to next
# appending 6419 to elf67
# Finished elf 67's inventory, moving to next
# appending 6003 to elf67
# Finished elf 67's inventory, moving to next
# appending 6884 to elf67
# Finished elf 67's inventory, moving to next
# appending 2315 to elf67
# Finished elf 67's inventory, moving to next
# appending 5745 to elf67
# Finished elf 67's inventory, moving to next
# appending 1341 to elf67
# Finished elf 67's inventory, moving to next
# appending 6370 to elf67
# Finished elf 67's inventory, moving to next
# appending 5430 to elf67
# Finished elf 67's inventory, moving to next
# appending 6442 to elf67
# Finished elf 67's inventory, moving to next
# appending 3156 to elf67
# Finished elf 67's inventory, moving to next
# Finished elf 68's inventory, moving to next
# appending 2112 to elf68
# Finished elf 68's inventory, moving to next
# appending 3970 to elf68
# Finished elf 68's inventory, moving to next
# appending 1000 to elf68
# Finished elf 68's inventory, moving to next
# appending 1981 to elf68
# Finished elf 68's inventory, moving to next
# appending 3528 to elf68
# Finished elf 68's inventory, moving to next
# appending 3490 to elf68
# Finished elf 68's inventory, moving to next
# appending 1510 to elf68
# Finished elf 68's inventory, moving to next
# appending 1629 to elf68
# Finished elf 68's inventory, moving to next
# appending 5413 to elf68
# Finished elf 68's inventory, moving to next
# appending 4277 to elf68
# Finished elf 68's inventory, moving to next
# appending 6347 to elf68
# Finished elf 68's inventory, moving to next
# appending 6134 to elf68
# Finished elf 68's inventory, moving to next
# appending 1855 to elf68
# Finished elf 68's inventory, moving to next
# Finished elf 69's inventory, moving to next
# appending 8848 to elf69
# Finished elf 69's inventory, moving to next
# appending 3187 to elf69
# Finished elf 69's inventory, moving to next
# appending 9361 to elf69
# Finished elf 69's inventory, moving to next
# appending 16338 to elf69
# Finished elf 69's inventory, moving to next
# appending 5644 to elf69
# Finished elf 69's inventory, moving to next
# Finished elf 70's inventory, moving to next
# appending 8477 to elf70
# Finished elf 70's inventory, moving to next
# appending 6983 to elf70
# Finished elf 70's inventory, moving to next
# appending 8052 to elf70
# Finished elf 70's inventory, moving to next
# appending 4156 to elf70
# Finished elf 70's inventory, moving to next
# appending 8204 to elf70
# Finished elf 70's inventory, moving to next
# appending 3216 to elf70
# Finished elf 70's inventory, moving to next
# appending 4797 to elf70
# Finished elf 70's inventory, moving to next
# appending 3024 to elf70
# Finished elf 70's inventory, moving to next
# appending 3499 to elf70
# Finished elf 70's inventory, moving to next
# appending 6006 to elf70
# Finished elf 70's inventory, moving to next
# Finished elf 71's inventory, moving to next
# appending 7326 to elf71
# Finished elf 71's inventory, moving to next
# appending 14394 to elf71
# Finished elf 71's inventory, moving to next
# appending 7169 to elf71
# Finished elf 71's inventory, moving to next
# appending 17160 to elf71
# Finished elf 71's inventory, moving to next
# Finished elf 72's inventory, moving to next
# appending 3282 to elf72
# Finished elf 72's inventory, moving to next
# appending 5582 to elf72
# Finished elf 72's inventory, moving to next
# appending 6657 to elf72
# Finished elf 72's inventory, moving to next
# appending 5435 to elf72
# Finished elf 72's inventory, moving to next
# appending 2096 to elf72
# Finished elf 72's inventory, moving to next
# appending 3038 to elf72
# Finished elf 72's inventory, moving to next
# appending 5747 to elf72
# Finished elf 72's inventory, moving to next
# appending 2545 to elf72
# Finished elf 72's inventory, moving to next
# appending 1927 to elf72
# Finished elf 72's inventory, moving to next
# appending 6331 to elf72
# Finished elf 72's inventory, moving to next
# appending 6785 to elf72
# Finished elf 72's inventory, moving to next
# appending 1199 to elf72
# Finished elf 72's inventory, moving to next
# appending 1794 to elf72
# Finished elf 72's inventory, moving to next
# Finished elf 73's inventory, moving to next
# appending 1471 to elf73
# Finished elf 73's inventory, moving to next
# appending 4089 to elf73
# Finished elf 73's inventory, moving to next
# appending 8406 to elf73
# Finished elf 73's inventory, moving to next
# appending 3811 to elf73
# Finished elf 73's inventory, moving to next
# appending 7060 to elf73
# Finished elf 73's inventory, moving to next
# appending 1164 to elf73
# Finished elf 73's inventory, moving to next
# appending 1042 to elf73
# Finished elf 73's inventory, moving to next
# appending 5968 to elf73
# Finished elf 73's inventory, moving to next
# appending 8721 to elf73
# Finished elf 73's inventory, moving to next
# Finished elf 74's inventory, moving to next
# appending 6191 to elf74
# Finished elf 74's inventory, moving to next
# appending 17967 to elf74
# Finished elf 74's inventory, moving to next
# appending 6680 to elf74
# Finished elf 74's inventory, moving to next
# appending 15071 to elf74
# Finished elf 74's inventory, moving to next
# Finished elf 75's inventory, moving to next
# appending 1811 to elf75
# Finished elf 75's inventory, moving to next
# appending 2960 to elf75
# Finished elf 75's inventory, moving to next
# appending 4046 to elf75
# Finished elf 75's inventory, moving to next
# appending 4196 to elf75
# Finished elf 75's inventory, moving to next
# appending 5271 to elf75
# Finished elf 75's inventory, moving to next
# appending 1982 to elf75
# Finished elf 75's inventory, moving to next
# appending 2324 to elf75
# Finished elf 75's inventory, moving to next
# appending 8928 to elf75
# Finished elf 75's inventory, moving to next
# appending 4517 to elf75
# Finished elf 75's inventory, moving to next
# Finished elf 76's inventory, moving to next
# appending 12525 to elf76
# Finished elf 76's inventory, moving to next
# appending 5174 to elf76
# Finished elf 76's inventory, moving to next
# appending 5986 to elf76
# ...
# appending 3125 to elf222
# Finished elf 222's inventory, moving to next
# appending 1897 to elf222
# Finished elf 222's inventory, moving to next
# appending 3675 to elf222
# Finished elf 222's inventory, moving to next
# appending 3688 to elf222
# Finished elf 222's inventory, moving to next
# appending 3393 to elf222
# Finished elf 222's inventory, moving to next
# appending 3794 to elf222
# Finished elf 222's inventory, moving to next
# appending 1146 to elf222
# Finished elf 222's inventory, moving to next
# Finished elf 223's inventory, moving to next
# appending 2603 to elf223
# Finished elf 223's inventory, moving to next
# appending 6838 to elf223
# Finished elf 223's inventory, moving to next
# appending 6037 to elf223
# Finished elf 223's inventory, moving to next
# appending 5540 to elf223
# Finished elf 223's inventory, moving to next
# appending 2335 to elf223
# Finished elf 223's inventory, moving to next
# appending 6837 to elf223
# Finished elf 223's inventory, moving to next
# appending 4425 to elf223
# Finished elf 223's inventory, moving to next
# appending 3437 to elf223
# Finished elf 223's inventory, moving to next
# appending 5965 to elf223
# Finished elf 223's inventory, moving to next
# appending 3449 to elf223
# Finished elf 223's inventory, moving to next
# appending 4752 to elf223
# Finished elf 223's inventory, moving to next
# appending 5173 to elf223
# Finished elf 223's inventory, moving to next
# appending 1971 to elf223
# Finished elf 223's inventory, moving to next
# Finished elf 224's inventory, moving to next
# appending 25800 to elf224
# Finished elf 224's inventory, moving to next
# appending 14272 to elf224
# Finished elf 224's inventory, moving to next
# appending 12870 to elf224
# Finished elf 224's inventory, moving to next
# Finished elf 225's inventory, moving to next
# appending 4840 to elf225
# Finished elf 225's inventory, moving to next
# appending 6051 to elf225
# Finished elf 225's inventory, moving to next
# appending 2429 to elf225
# Finished elf 225's inventory, moving to next
# appending 2372 to elf225
# Finished elf 225's inventory, moving to next
# appending 2533 to elf225
# Finished elf 225's inventory, moving to next
# appending 4184 to elf225
# Finished elf 225's inventory, moving to next
# appending 4051 to elf225
# Finished elf 225's inventory, moving to next
# appending 5449 to elf225
# Finished elf 225's inventory, moving to next
# appending 1321 to elf225
# Finished elf 225's inventory, moving to next
# appending 2738 to elf225
# Finished elf 225's inventory, moving to next
# appending 4450 to elf225
# Finished elf 225's inventory, moving to next
# appending 4473 to elf225
# Finished elf 225's inventory, moving to next
# appending 4618 to elf225
# Finished elf 225's inventory, moving to next
# appending 2936 to elf225
# Finished elf 225's inventory, moving to next
# appending 5818 to elf225
# Finished elf 225's inventory, moving to next
# Finished elf 226's inventory, moving to next
# appending 9966 to elf226
# Finished elf 226's inventory, moving to next
# appending 9565 to elf226
# Finished elf 226's inventory, moving to next
# appending 4598 to elf226
# Finished elf 226's inventory, moving to next
# appending 6548 to elf226
# Finished elf 226's inventory, moving to next
# appending 6832 to elf226
# Finished elf 226's inventory, moving to next
# appending 1749 to elf226
# Finished elf 226's inventory, moving to next
# Finished elf 227's inventory, moving to next
# appending 6333 to elf227
# Finished elf 227's inventory, moving to next
# appending 7723 to elf227
# Finished elf 227's inventory, moving to next
# appending 7084 to elf227
# Finished elf 227's inventory, moving to next
# appending 7305 to elf227
# Finished elf 227's inventory, moving to next
# appending 2609 to elf227
# Finished elf 227's inventory, moving to next
# appending 8143 to elf227
# Finished elf 227's inventory, moving to next
# appending 10400 to elf227
# Finished elf 227's inventory, moving to next
# appending 7867 to elf227
# Finished elf 227's inventory, moving to next
# Finished elf 228's inventory, moving to next
# appending 2652 to elf228
# Finished elf 228's inventory, moving to next
# appending 6421 to elf228
# Finished elf 228's inventory, moving to next
# appending 6630 to elf228
# Finished elf 228's inventory, moving to next
# appending 4124 to elf228
# Finished elf 228's inventory, moving to next
# appending 8490 to elf228
# Finished elf 228's inventory, moving to next
# appending 8618 to elf228
# Finished elf 228's inventory, moving to next
# appending 6380 to elf228
# Finished elf 228's inventory, moving to next
# appending 2636 to elf228
# Finished elf 228's inventory, moving to next
# appending 8045 to elf228
# Finished elf 228's inventory, moving to next
# Finished elf 229's inventory, moving to next
# appending 1382 to elf229
# Finished elf 229's inventory, moving to next
# appending 6541 to elf229
# Finished elf 229's inventory, moving to next
# appending 2533 to elf229
# Finished elf 229's inventory, moving to next
# appending 3419 to elf229
# Finished elf 229's inventory, moving to next
# appending 3661 to elf229
# Finished elf 229's inventory, moving to next
# appending 4779 to elf229
# Finished elf 229's inventory, moving to next
# appending 5466 to elf229
# Finished elf 229's inventory, moving to next
# appending 6163 to elf229
# Finished elf 229's inventory, moving to next
# appending 5536 to elf229
# Finished elf 229's inventory, moving to next
# appending 4844 to elf229
# Finished elf 229's inventory, moving to next
# appending 2600 to elf229
# Finished elf 229's inventory, moving to next
# appending 1126 to elf229
# Finished elf 229's inventory, moving to next
# appending 4297 to elf229
# Finished elf 229's inventory, moving to next
# Finished elf 230's inventory, moving to next
# appending 4541 to elf230
# Finished elf 230's inventory, moving to next
# appending 10317 to elf230
# Finished elf 230's inventory, moving to next
# appending 5900 to elf230
# Finished elf 230's inventory, moving to next
# appending 4278 to elf230
# Finished elf 230's inventory, moving to next
# appending 2540 to elf230
# Finished elf 230's inventory, moving to next
# appending 4385 to elf230
# Finished elf 230's inventory, moving to next
# appending 3048 to elf230
# Finished elf 230's inventory, moving to next
# appending 3079 to elf230
# Finished elf 230's inventory, moving to next
# Finished elf 231's inventory, moving to next
# appending 7542 to elf231
# Finished elf 231's inventory, moving to next
# appending 4938 to elf231
# Finished elf 231's inventory, moving to next
# appending 1913 to elf231
# Finished elf 231's inventory, moving to next
# appending 7746 to elf231
# Finished elf 231's inventory, moving to next
# appending 7472 to elf231
# Finished elf 231's inventory, moving to next
# appending 7621 to elf231
# Finished elf 231's inventory, moving to next
# appending 1307 to elf231
# Finished elf 231's inventory, moving to next
# appending 2142 to elf231
# Finished elf 231's inventory, moving to next
# Finished elf 232's inventory, moving to next
# appending 12358 to elf232
# Finished elf 232's inventory, moving to next
# appending 6813 to elf232
# Finished elf 232's inventory, moving to next
# appending 15347 to elf232
# Finished elf 232's inventory, moving to next
# appending 14448 to elf232
# Finished elf 232's inventory, moving to next
# appending 4584 to elf232
# Finished elf 232's inventory, moving to next
# Finished elf 233's inventory, moving to next
# appending 8653 to elf233
# Finished elf 233's inventory, moving to next
# appending 14358 to elf233
# Finished elf 233's inventory, moving to next
# appending 1689 to elf233
# Finished elf 233's inventory, moving to next
# appending 3466 to elf233
# Finished elf 233's inventory, moving to next
# appending 13581 to elf233
# Finished elf 233's inventory, moving to next
# Finished elf 234's inventory, moving to next
# appending 18460 to elf234
# Finished elf 234's inventory, moving to next
# appending 15717 to elf234
# Finished elf 234's inventory, moving to next
# appending 11921 to elf234
# Finished elf 234's inventory, moving to next
# Finished elf 235's inventory, moving to next
# appending 5002 to elf235
# Finished elf 235's inventory, moving to next
# appending 1450 to elf235
# Finished elf 235's inventory, moving to next
# appending 1233 to elf235
# Finished elf 235's inventory, moving to next
# appending 5553 to elf235
# Finished elf 235's inventory, moving to next
# appending 2723 to elf235
# Finished elf 235's inventory, moving to next
# appending 3811 to elf235
# Finished elf 235's inventory, moving to next
# appending 4765 to elf235
# Finished elf 235's inventory, moving to next
# appending 1001 to elf235
# Finished elf 235's inventory, moving to next
# appending 4513 to elf235
# Finished elf 235's inventory, moving to next
# appending 5847 to elf235
# Finished elf 235's inventory, moving to next
# appending 4403 to elf235
# Finished elf 235's inventory, moving to next
# Finished elf 236's inventory, moving to next
# appending 20065 to elf236
# Finished elf 236's inventory, moving to next
# appending 10696 to elf236
# Finished elf 236's inventory, moving to next
# Finished elf 237's inventory, moving to next
# appending 8007 to elf237
# Finished elf 237's inventory, moving to next
# appending 1090 to elf237
# Finished elf 237's inventory, moving to next
# appending 2875 to elf237
# Finished elf 237's inventory, moving to next
# appending 4585 to elf237
# Finished elf 237's inventory, moving to next
# appending 7707 to elf237
# Finished elf 237's inventory, moving to next
# appending 7823 to elf237
# Finished elf 237's inventory, moving to next
# appending 2009 to elf237
# Finished elf 237's inventory, moving to next
# appending 8498 to elf237
# Finished elf 237's inventory, moving to next
# Finished elf 238's inventory, moving to next
# appending 9586 to elf238
# Finished elf 238's inventory, moving to next
# appending 8143 to elf238
# Finished elf 238's inventory, moving to next
# appending 8021 to elf238
# Finished elf 238's inventory, moving to next
# appending 4245 to elf238
# Finished elf 238's inventory, moving to next
# appending 7291 to elf238
# Finished elf 238's inventory, moving to next
# appending 3936 to elf238
# Finished elf 238's inventory, moving to next
# appending 11899 to elf238
# Finished elf 238's inventory, moving to next
# Finished elf 239's inventory, moving to next
# appending 26024 to elf239
# Finished elf 239's inventory, moving to next
# Finished elf 240's inventory, moving to next
# appending 14163 to elf240
# Finished elf 240's inventory, moving to next
# appending 9586 to elf240
# Finished elf 240's inventory, moving to next
# appending 12371 to elf240
# Finished elf 240's inventory, moving to next
# appending 2127 to elf240
# Finished elf 240's inventory, moving to next
# appending 4436 to elf240
# Finished elf 240's inventory, moving to next
# Finished elf 241's inventory, moving to next
# appending 2613 to elf241
# Finished elf 241's inventory, moving to next
# appending 6450 to elf241
# Finished elf 241's inventory, moving to next
# appending 3236 to elf241
# Finished elf 241's inventory, moving to next
# appending 7142 to elf241
# Finished elf 241's inventory, moving to next
# appending 6570 to elf241
# Finished elf 241's inventory, moving to next
# appending 6405 to elf241
# Finished elf 241's inventory, moving to next
# appending 2444 to elf241
# Finished elf 241's inventory, moving to next
# appending 3243 to elf241
# Finished elf 241's inventory, moving to next
# appending 6166 to elf241
# Finished elf 241's inventory, moving to next
# appending 7090 to elf241
# Finished elf 241's inventory, moving to next
# appending 3461 to elf241
# Finished elf 241's inventory, moving to next
# appending 6534 to elf241
# Finished elf 241's inventory, moving to next
# Finished elf 242's inventory, moving to next
# appending 3176 to elf242
# Finished elf 242's inventory, moving to next
# appending 4477 to elf242
# Finished elf 242's inventory, moving to next
# appending 4562 to elf242
# Finished elf 242's inventory, moving to next
# appending 3589 to elf242
# Finished elf 242's inventory, moving to next
# appending 5280 to elf242
# Finished elf 242's inventory, moving to next
# appending 5548 to elf242
# Finished elf 242's inventory, moving to next
# appending 3708 to elf242
# Finished elf 242's inventory, moving to next
# appending 4632 to elf242
# Finished elf 242's inventory, moving to next
# appending 3836 to elf242
# Finished elf 242's inventory, moving to next
# appending 4171 to elf242
# Finished elf 242's inventory, moving to next
# appending 5284 to elf242
# Finished elf 242's inventory, moving to next
# appending 3667 to elf242
# Finished elf 242's inventory, moving to next
# appending 3313 to elf242
# Finished elf 242's inventory, moving to next
# appending 4312 to elf242
# Finished elf 242's inventory, moving to next
# Finished elf 243's inventory, moving to next
# appending 12262 to elf243
# Finished elf 243's inventory, moving to next
# appending 7518 to elf243
# Finished elf 243's inventory, moving to next
# appending 13586 to elf243
# Finished elf 243's inventory, moving to next
# appending 14339 to elf243
# Finished elf 243's inventory, moving to next
# appending 2951 to elf243
# Finished elf 243's inventory, moving to next
# Finished elf 244's inventory, moving to next
# appending 30207 to elf244
# Finished elf 244's inventory, moving to next
# Finished elf 245's inventory, moving to next
# appending 3979 to elf245
# Finished elf 245's inventory, moving to next
# appending 2163 to elf245
# Finished elf 245's inventory, moving to next
# appending 7147 to elf245
# Finished elf 245's inventory, moving to next
# appending 3726 to elf245
# Finished elf 245's inventory, moving to next
# appending 4358 to elf245
# Finished elf 245's inventory, moving to next
# appending 7572 to elf245
# Finished elf 245's inventory, moving to next
# appending 3345 to elf245
# Finished elf 245's inventory, moving to next
# appending 1296 to elf245
# Finished elf 245's inventory, moving to next
# appending 2755 to elf245
# Finished elf 245's inventory, moving to next
# appending 4608 to elf245
# Finished elf 245's inventory, moving to next
# Finished elf 246's inventory, moving to next
# appending 5723 to elf246
# Finished elf 246's inventory, moving to next
# appending 3754 to elf246
# Finished elf 246's inventory, moving to next
# appending 2684 to elf246
# Finished elf 246's inventory, moving to next
# Finished elf 247's inventory, moving to next
# appending 19384 to elf247
# Finished elf 247's inventory, moving to next
# appending 3722 to elf247
# Finished elf 247's inventory, moving to next
# Finished elf 248's inventory, moving to next
# appending 2024 to elf248
# Finished elf 248's inventory, moving to next
# appending 8540 to elf248
# Finished elf 248's inventory, moving to next
# appending 6504 to elf248
# Finished elf 248's inventory, moving to next
# appending 12081 to elf248
# Finished elf 248's inventory, moving to next
# appending 4812 to elf248
# Finished elf 248's inventory, moving to next
# appending 3647 to elf248
# Finished elf 248's inventory, moving to next
# appending 2731 to elf248
# Finished elf 248's inventory, moving to next
# Finished elf 249's inventory, moving to next
# appending 18117 to elf249
# Finished elf 249's inventory, moving to next
# appending 13193 to elf249
# Finished elf 249's inventory, moving to next
# appending 13899 to elf249
# Finished elf 249's inventory, moving to next
# appending 19853 to elf249
# Finished elf 249's inventory, moving to next
# Finished elf 250's inventory, moving to next
# appending 3533 to elf250
# Finished elf 250's inventory, moving to next
# appending 4991 to elf250
# Finished elf 250's inventory, moving to next
# appending 2034 to elf250
# Finished elf 250's inventory, moving to next
# appending 3914 to elf250
# Finished elf 250's inventory, moving to next
# appending 5920 to elf250
# Finished elf 250's inventory, moving to next
# appending 2455 to elf250
# Finished elf 250's inventory, moving to next
# appending 2660 to elf250
# Finished elf 250's inventory, moving to next
# appending 3175 to elf250
# Finished elf 250's inventory, moving to next
# appending 1410 to elf250
# Finished elf 250's inventory, moving to next
# appending 1127 to elf250
# Finished elf 250's inventory, moving to next
# appending 2272 to elf250
# Finished elf 250's inventory, moving to next
# appending 3689 to elf250
# Finished elf 250's inventory, moving to next
# appending 5804 to elf250
# Finished elf 250's inventory, moving to next
# appending 1311 to elf250
# Finished elf 250's inventory, moving to next
# appending 1121 to elf250
# Finished elf 250's inventory, moving to next

# %%
def compute_totals(data: List[List[int]])-> List[int]:
  data = [
    sum(elf) for elf in data
    ]

  return data

# %%
elf_totals = compute_totals(elf_inventories)
elf_totals[:10]
# Out:
# [36756, 70369, 46030, 55237, 49273, 61698, 41206, 44233, 56367, 44201]

# %% [markdown]
# # Part 2
#
# By the time you calculate the answer to the Elves' question, they've already realized that the Elf carrying the most Calories of food might eventually run out of snacks.
#
# To avoid this unacceptable situation, the Elves would instead like to know the total Calories carried by the top three Elves carrying the most Calories. That way, even if one of those Elves runs out of snacks, they still have two backups.
#
# In the example above, the top three Elves are the fourth Elf (with `24000` Calories), then the third Elf (with `11000` Calories), then the fifth Elf (with `10000` Calories). The sum of the Calories carried by these three elves is `45000`.
#
# Find the top three Elves carrying the most Calories. How many Calories are those Elves carrying in total?
#
# -----
#
# Note: This problem originally appeared in 2022's Advent of Code < https://adventofcode.com/2022/day/1 >.
